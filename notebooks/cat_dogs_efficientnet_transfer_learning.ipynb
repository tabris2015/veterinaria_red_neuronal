# %%
# IMG_SIZE is determined by EfficientNet model choice
IMG_SIZE = 224

# %%
import tensorflow as tf

# %%
import tensorflow_datasets as tfds

batch_size = 64

dataset_name = "cats_vs_dogs"
ds, ds_info = tfds.load(
    dataset_name, split=["train"], with_info=True, as_supervised=True
)

ds_train = tfds.load(
    dataset_name, split=["train[:80%]"], as_supervised=True
)[0]

ds_test = tfds.load(
    dataset_name, split=["train[80%:]"], as_supervised=True
)[0]


NUM_CLASSES = ds_info.features["label"].num_classes
print(ds_info.features['label'].num_classes)
print(type(ds_train))
# Out:
# 2
# <class 'tensorflow.python.data.ops.dataset_ops.PrefetchDataset'>

# %%
size = (IMG_SIZE, IMG_SIZE)
ds_train = ds_train.map(lambda image, label: (tf.image.resize(image, size), label))
ds_test = ds_test.map(lambda image, label: (tf.image.resize(image, size), label))

# %%
import matplotlib.pyplot as plt


def format_label(label):
    string_label = label_info.int2str(label)
    return string_label


label_info = ds_info.features["label"]
for i, (image, label) in enumerate(ds_train.take(12)):
    ax = plt.subplot(4, 3, i + 1)
    plt.imshow(image.numpy().astype("uint8"))
    plt.title("{}".format(format_label(label)))
    plt.axis("off")

# %%
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

img_augmentation = Sequential(
    [
        preprocessing.RandomRotation(factor=0.15),
        preprocessing.RandomTranslation(height_factor=0.1, width_factor=0.1),
        preprocessing.RandomFlip(),
        preprocessing.RandomContrast(factor=0.1),
    ],
    name="img_augmentation",
)

# %%
for image, label in ds_train.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        aug_img = img_augmentation(tf.expand_dims(image, axis=0))
        plt.imshow(aug_img[0].numpy().astype("uint8"))
        plt.title("{}".format(format_label(label)))
        plt.axis("off")

# %%
# One-hot / categorical encoding
def input_preprocess(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label


ds_train = ds_train.map(
    input_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE
)
ds_train = ds_train.batch(batch_size=batch_size, drop_remainder=True)
ds_train = ds_train.prefetch(tf.data.experimental.AUTOTUNE)

ds_test = ds_test.map(input_preprocess)
ds_test = ds_test.batch(batch_size=batch_size, drop_remainder=True)

# %%
import matplotlib.pyplot as plt


def plot_hist(hist):
    plt.plot(hist.history["accuracy"])
    plt.plot(hist.history["val_accuracy"])
    plt.title("model accuracy")
    plt.ylabel("accuracy")
    plt.xlabel("epoch")
    plt.legend(["train", "validation"], loc="upper left")
    plt.show()

# %%
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.applications import EfficientNetB0


def build_model(num_classes):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = img_augmentation(inputs)
    model = EfficientNetB0(include_top=False, input_tensor=x, weights="imagenet")

    # Freeze the pretrained weights
    model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    x = layers.BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(NUM_CLASSES, activation="softmax", name="pred")(x)

    # Compile
    model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-2)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
epochs = 30
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        "cats_dogs_best_colab1.h5",
        monitor="val_loss",
        save_best_only=True,
        verbose=1),
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,
        verbose=1),
]
model = build_model(num_classes=NUM_CLASSES)

hist = model.fit(ds_train, epochs=epochs, validation_data=ds_test, callbacks=callbacks)
plot_hist(hist)
# Out:
# Epoch 1/30
#   2/290 [..............................] - ETA: 14s - loss: 0.8213 - accuracy: 0.6406WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0309s vs `on_train_batch_end` time: 0.0712s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0309s vs `on_train_batch_end` time: 0.0712s). Check your callbacks.
# 290/290 [==============================] - ETA: 0s - loss: 0.3916 - accuracy: 0.9168
# Epoch 00001: val_loss improved from inf to 0.09912, saving model to cats_dogs_best_colab1.h5
# 290/290 [==============================] - 40s 138ms/step - loss: 0.3916 - accuracy: 0.9168 - val_loss: 0.0991 - val_accuracy: 0.9763
# Epoch 2/30
# 290/290 [==============================] - ETA: 0s - loss: 0.3379 - accuracy: 0.9273
# Epoch 00002: val_loss improved from 0.09912 to 0.09025, saving model to cats_dogs_best_colab1.h5
# 290/290 [==============================] - 39s 134ms/step - loss: 0.3379 - accuracy: 0.9273 - val_loss: 0.0902 - val_accuracy: 0.9757
# Epoch 3/30
# 290/290 [==============================] - ETA: 0s - loss: 0.2799 - accuracy: 0.9279
# Epoch 00003: val_loss improved from 0.09025 to 0.07045, saving model to cats_dogs_best_colab1.h5
# 290/290 [==============================] - 38s 132ms/step - loss: 0.2799 - accuracy: 0.9279 - val_loss: 0.0705 - val_accuracy: 0.9811
# Epoch 4/30
# 290/290 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.9294
# Epoch 00004: val_loss improved from 0.07045 to 0.05978, saving model to cats_dogs_best_colab1.h5
# 290/290 [==============================] - 39s 134ms/step - loss: 0.2385 - accuracy: 0.9294 - val_loss: 0.0598 - val_accuracy: 0.9833
# Epoch 5/30
# 290/290 [==============================] - ETA: 0s - loss: 0.2037 - accuracy: 0.9335
# Epoch 00005: val_loss did not improve from 0.05978
# 290/290 [==============================] - 38s 130ms/step - loss: 0.2037 - accuracy: 0.9335 - val_loss: 0.0645 - val_accuracy: 0.9774
# Epoch 6/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9355
# Epoch 00006: val_loss improved from 0.05978 to 0.05307, saving model to cats_dogs_best_colab1.h5
# 290/290 [==============================] - 38s 132ms/step - loss: 0.1837 - accuracy: 0.9355 - val_loss: 0.0531 - val_accuracy: 0.9813
# Epoch 7/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9349
# Epoch 00007: val_loss did not improve from 0.05307
# 290/290 [==============================] - 38s 130ms/step - loss: 0.1745 - accuracy: 0.9349 - val_loss: 0.0586 - val_accuracy: 0.9807
# Epoch 8/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9324
# Epoch 00008: val_loss improved from 0.05307 to 0.04980, saving model to cats_dogs_best_colab1.h5
# 290/290 [==============================] - 39s 133ms/step - loss: 0.1749 - accuracy: 0.9324 - val_loss: 0.0498 - val_accuracy: 0.9835
# Epoch 9/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9357
# Epoch 00009: val_loss improved from 0.04980 to 0.04532, saving model to cats_dogs_best_colab1.h5
# 290/290 [==============================] - 38s 133ms/step - loss: 0.1669 - accuracy: 0.9357 - val_loss: 0.0453 - val_accuracy: 0.9857
# Epoch 10/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9378
# Epoch 00010: val_loss improved from 0.04532 to 0.04252, saving model to cats_dogs_best_colab1.h5
# 290/290 [==============================] - 39s 133ms/step - loss: 0.1633 - accuracy: 0.9378 - val_loss: 0.0425 - val_accuracy: 0.9865
# Epoch 11/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9369
# Epoch 00011: val_loss did not improve from 0.04252
# 290/290 [==============================] - 38s 131ms/step - loss: 0.1643 - accuracy: 0.9369 - val_loss: 0.0524 - val_accuracy: 0.9822
# Epoch 12/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1590 - accuracy: 0.9382
# Epoch 00012: val_loss improved from 0.04252 to 0.04248, saving model to cats_dogs_best_colab1.h5
# 290/290 [==============================] - 39s 136ms/step - loss: 0.1590 - accuracy: 0.9382 - val_loss: 0.0425 - val_accuracy: 0.9846
# Epoch 13/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9374
# Epoch 00013: val_loss did not improve from 0.04248
# 290/290 [==============================] - 39s 133ms/step - loss: 0.1615 - accuracy: 0.9374 - val_loss: 0.0498 - val_accuracy: 0.9837
# Epoch 14/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1559 - accuracy: 0.9400
# Epoch 00014: val_loss did not improve from 0.04248
# 290/290 [==============================] - 38s 132ms/step - loss: 0.1559 - accuracy: 0.9400 - val_loss: 0.0539 - val_accuracy: 0.9822
# Epoch 15/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1607 - accuracy: 0.9350
# Epoch 00015: val_loss did not improve from 0.04248
# 290/290 [==============================] - 38s 131ms/step - loss: 0.1607 - accuracy: 0.9350 - val_loss: 0.0524 - val_accuracy: 0.9833
# Epoch 16/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1596 - accuracy: 0.9368
# Epoch 00016: val_loss did not improve from 0.04248
# 290/290 [==============================] - 38s 132ms/step - loss: 0.1596 - accuracy: 0.9368 - val_loss: 0.0475 - val_accuracy: 0.9844
# Epoch 17/30
# 290/290 [==============================] - ETA: 0s - loss: 0.1647 - accuracy: 0.9359
# Epoch 00017: val_loss did not improve from 0.04248
# 290/290 [==============================] - 38s 132ms/step - loss: 0.1647 - accuracy: 0.9359 - val_loss: 0.0511 - val_accuracy: 0.9835
# Epoch 00017: early stopping

# %%
# load saved model
model.save('cats_dogs_efficientnet_colab.h5')
